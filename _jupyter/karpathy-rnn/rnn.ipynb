# %% [markdown]
# # RNNs!
# Let's follow karpathy's blog post: https://karpathy.github.io/2015/05/21/rnn-effectiveness/

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 1238559 characters, 95 unique.
# ----
#  w!7ZS2K*r”Œ&*aUtp[XsRCMQ%xϰח5i9-)τOTeϰfDPw5“l‘
# yyp5R?EXI3?nŒoHxw 9Icςη8K67$ηYU#@rVv]$1R23cAς!c(eUl—”!%f8?UZG“Pdw4X-$.P A.o.kS#cUPQy—BN5:IςςIAY’ϰdŒeL@kWRqr,4οP3)4x]T8ς.b-ח$zς-f’m!v$RRCDhOE/ς94t”“*1T2-h
# ----
# iter 0, loss: 113.846919
# ----
#  u iS2s Re re e  fsrtT tTSi rue rp.i2A tt5X t5.MtrA C
# HC -sbLu PTRs5HsEd
# .Fn..MinuPtfHMos.h    P sFH
# rt9pCtf T
#
# W
# itAiHtti TM5sYtiss7
# 14aHRC ne C   HH Oe  oTWs dnC H #
# e
#  hW
# e
# G
# FyW P
# -cC   t -TP
# ----
# iter 100, loss: 113.291144
# ----
#  rda  mnasah rPH PTPbXea1yi CH
#  1APl H.CLe1s .Ea STECHAP r
#  CAA6 Tnhi18td ThOt D
# TAPTWml
#     TAPTE n Dr H4knCHge.lha e .Pibd. HAil 11Ay 3.PACHASbHsaPeai .
# d .nRhHAPTrR o1 e Be7
# T  CHHPTE.   l
#  R  1H5E
# ----
# iter 200, loss: 110.372605
# ----
#  C . as      C  S  o                    w H      C  1 f D         N tb  R   Ca       o,              BW s   to1s    t    Ac      L T W
#   n    hu H2D
#
#
#        e  e)   h   D       A
# ----
# iter 300, loss: 107.459919
# ----
#   s  otnr aigseWthe tedarL nagi  biicaevt odlaotn al .oudllta h.ah athaehNatssiol oonoeeosoa3 osvinpnoeae htyasetheile,rks th   g.
# am ocG Cf  dts rtcqethto,  niaceeu tdhy,tedeet.i
# ed Saourhlugiv  wt
# ----
# iter 400, loss: 105.105658
# ----
#   sdy toe  ]Eeuneadl  o e  y T9i’eene.ineaileehth
#
# oh nacolnusilesnhmatKeai   ljheaihaa g  he  pRt no utteageid .  H.
#  Aheelg ina inkmdaceealest
#
# wwhsitelensekilili enn  inltDveatcs th ”tesgtnutrki i!e
# ----
# iter 500, loss: 102.569629
# ----
#  ta od  ifetic.ir serde ine fh  ynwboX. o.  al. Nanoar. Ka  khee,se het an
# . t pnos.hrt oae“theo.ol uhherat “f tane heeenre
# ds.Thhat oos,tn e, he,lonSe haa dtftcuee;lleleeeds thCP out herintuenu.tone n
# ----
# iter 600, loss: 99.793635
# ----
#  ee dhs tosfd,Sle soyse esvlnespteth .ttuimnnrRcbesevis tishamstatthoth ehan me
# resyprondaBr,,scaivkewthdes ath aog
# trsa. —I7es hespr ffe so
#   un s ten enan nddnevld jn ah’esdans .matonftheoem ag
#  RBnh
# ----
# iter 700, loss: 97.109555
# ----
#    Biled fpsal aoir pinee Srssurus, aagd toorsells irt, s     o   hisetykise o in.on g Werdoghe, tPsunndnsann wion wqb, ” ptincee siwrdaeisanre Sgongs nthon — d fase s.
#
#
#      —To hocm
#   he banTn.
#
#
# “
# ----
# iter 800, loss: 94.388920
# ----
#  nt
# m 1mann betifpeea89ini,hsiemant reenssti tothe uth  fe ti; .  n ;n yinnceetWanime ot so antasetravSubfor ary;d fred twhirant eatathetsd atin pof eiu cisat
#  sie
#  shisrotpe jtohessiater fuor wh, jcca
# ----
# iter 900, loss: 91.984967
# ----
#   ar vedefecthasit
# Ssmlid yeaver. thade Dos,d
#
# w he ate nle theimtSh, pe ’ebs tinthengheksind fher  ouson
# bellerg ak.”  he
# Psogin bhesi
# R Las Gr at—ee
# hat r2lomd
#  Eoilelr bagapelth abcy c.el(tod boven,
# ----
# iter 1000, loss: 89.738395
# ----
#  bs qoIwe ayditth oe the  a” the naPaf
# of shen Avy, boaes they , 6n’go-a
#  Iatocora, maftarpanid;na, irepcle,cpuved.—kinderof cofppef matsetrree wCam
#  hat gatctomo A‘thlad m bof s thewe me sxmar) jilly
# ----
# iter 1100, loss: 87.590317
# ----
#   hartest we
# uhand, Ir ber ve be, Whaviv fres i’soare piet beongefaslr.ge Woe ; “or B snmesrchaared, ghel seSatl stye ines ap thics alizt woalt locee rele meos of
# arCe lhirsl ouds of sliSns.
# ““hWrf aio
# ----
# iter 1200, loss: 85.613507
# ----
#  rlcointu PThesmdeciltanels yorne sin, iees urgce.
# “p beond hesaprlpe s al  eo
# se hhereil iy diseestr,
# she, wosiud teed
# oc.
# are iofrr who aatrrin iap irel tin.te seoonse buek fotne sis;, siawe cereraco
# ----
# iter 1300, loss: 83.599823
# ----
#  t u; eh soudtautiw. thounw alen gitemtthe o I he outtin Sorind, mor bo ween tba hal thar Co fhe The tim o—mvos an chas peer t o the rie edaaait atrrof by urathe,
# uf va theca al hot
#  hewe oft, Ic iGd p
# ----
# iter 1400, loss: 81.902130
# ----
#  ess thlr thate he et saf avepcone theivasas. Fhe tia mapllress meyesttcand tes a? aons o ff os may ines din mac worathin tot cat ide seont Ta massvit sa bdetm, Wfpethevals
# ane m or Wiafs afinn-va to a
# ----
# iter 1500, loss: 80.179816
# ----
#  oes, en-inesd
#  he the of thetele ore dece prory
# ir veng peded lesingale De lis; cof mul? ing heis, segeun sawethe lotmalnd
# thorer in mowp to tor, llithonn ac; we hal, teirge wonus whes to here litos,
# ----
# iter 1600, loss: 78.688406
# ----
#  r ons and indtwbegorg oy it pe ne he thored wounr lacs bo a pooxccins Irr wps ir  ang ons It am he ons releme pare morr pow a thiptsas wareas In, vecist a nos the tou
# t bin tin kiu.gw gan
# w ardaed rar
# ----
# iter 1700, loss: 77.323663
# ----
#  kimcingp ongrtt tos ny an gho
# t Thae thecIthe thbely, wondip so
# pes fand il. 7Sfoueis
# ofd,
# je rooutpthin Elinsrot
# Nfctir tSan
# F shons ine as
# Hnenthe akst lag
# sual, Qocstats, negt rone tond I I
# sore,
# ----
# iter 1800, loss: 76.039702
# ----
#  y ovir,he the ny pin, of I “n aambes —urale. howl Dha
# s, Noe  fu Cot lumt whe wth was whivan ]oyr hale sonlegudet
# highicr of Thathekls thinecKne h in oanroveleor Lut  of vo mot
# bout
# In ared hban midit
# ----
# iter 1900, loss: 74.807533
# ----
#  , the Phigesrpolaleim the ol,nn Hnesyoun iunt avamg.—pa
# phat uatt authe culs thath. thot er ores mous of
#  ha the abe yored, sthared
# the cSovnreuE. Burepe eut
# —try spyand wate d thely Dobeke, at; — p a
# ----
# iter 2000, loss: 73.668186
# ----
#  nse’tyof to inp.
# Buleds noubeded gimget thas io’e pypoghan par —ut line the ap. dorle fothe-ledan at nonges, and Sond toctll ssicnd, dlonegd shas. p bos the koat pascejikg—wnow ind thoro icolates o s,
# ----
# iter 2100, loss: 72.630664
# ----
#  anu on and oond an yovo?g Iuild I fach moukingtun; thef solcencer., 9ord seoessSithalts, wlaathenf,
# ne sin o elonls  nad fHlin tham Iand lithlt uuf aft yaz, ne the wlet indrye bomorptad son.” wird suc
# ----
# iter 2200, loss: 71.721298
# ----
#  n s hitteod orat” it
#  ralet af tharderon (pded me
# to wothe, blegrnosed the thald fun laye
# the al. whele o goreraete heibked thipe
# singir ion orcouth inreke go thele spos, shy than, eele fore s Aaps an
# ----
# iter 2300, loss: 70.729257
# ----
#  me lto hrond ed an,or. mosk old ou heplibpem ellard penot her,  anyis he in ine.
# glun ar on
# Ad PThos  an o mothin raen hony ersine tagheras wheor shrelasing ao Cthe ine, hethinenlede
#  whin , Far coob
# ----
# iter 2400, loss: 69.863632
# ----
#  ed chowthe. ound an.
# I I te.
# I or novthe
# whaing a los stole be soCv he
# ond belat Nhegsr athely baed a”  het ans aves iudt a at —Iu whe cilet ingae bagtharn;ulinilu serigh meit’I anll the boonce awUghe
# ----
# iter 2500, loss: 68.879631
# ----
#  ron in, anko thelare oule uGlbonsas thateid had thabl in chaiden inlyant canree dtmat be bpindeg sherark.s re glors lufred jion; to bow tonan s, toe” co soferas
#
# teiseirtoudin a
# haled the the sat the
# ----
# iter 2600, loss: 68.194189
# ----
#  o delof ntt can out yo neoncla thipplhalguklfheos. Aftoich, it cot imerded, fond.”—e xpad wosd inde’sy, nout malrojlhe fwt thy am thand, ho gltices cinggin s-, at re ane oore seun droud me thastwudl,
# ----
# iter 2700, loss: 67.500318
# ----
#  ?ere ot IEm lel
# gherss—4elcedyore In Dpowlas bocicAlets thig owo the malmrlod lpepithinct anp urh wa.sf as a pon glouelr, seyeng w to wan thkiigm lorto s,
# mupit toy r;’d.n’ whastrneden the tre, afde,
# ----
# iter 2800, loss: 66.530136
# ----
#   sramron, our’d I pan foolit
# a thews anm a hyelinrg haned ofe to tuirh mtes bnons wur bomes atatey, at neant Io tofe hilleik ther se-solind ancar, nutclirese
# o mofgis norat the!fcone wiof an —inelit u
# ----
# iter 2900, loss: 65.765012
# ----
#  t, the blasachh the seglik Peverae lole numind or, ar bacre
# rhens
# vound angoure sedtsrenkd ans wh. nug s intas ar him dulpv. Idlas has haesyr
# yougoch elaps theask, in laus sndeameskket the meclinnfesl
# ----
# iter 3000, loss: 65.110266
# ----
#   thow
# mout onry hoit womgunlle, wod stcided ile. “I lowth
# as toit  nord hin nobe.singe tisg Ixshe at afdith
# cercar
# nomsto avn blbenceend on! be vly htof parf taMe pans thad of thes he his waghlern lau
# ----
# iter 3100, loss: 64.588208
# ----
#   mipusinglvat, qine cast mivlitet it im ino tost of uva.
#
# t r.
#
# he bing suse harcild eor, oupiang mytit cnoutiigin mutly
# iwte fade bolimtlot sh o hast atyod, boca
# t oe hith keon ho nerter hyand, “isou
# ----
# iter 3200, loss: 64.346893
# ----
#  ftecn in. I yrone wiltey romacing nadoery S wo.
#
#
# I
# ed wvink sime
# hhes plongs ayeew thihis a yilg teorimgoe thpcaring gev hlloucat hlod toong, of Ealef it thiddned cheltdnmed ir haskiogsto seed ange,
# ----
# iter 3300, loss: 63.930980
# ----
#  bresaug, fouthth,—my uf an sust ffemof sord
# ybagt unQur ond sodgrougit wheuns negy sakind at agellar Ing cigrasree herure.—Ir at uofaedan chermleich iI meame thesed ud and;puyed, of mrey at tomds brul
# ----
# iter 3400, loss: 63.579291
# ----
#  . Amaz
# teult “ncabluese temegh atited be ting whee
# tou iH wis Feit as toum no’
# ly to sadik bangund mathe Th hat te lered thes sndap-froy botenp—cang ase tely ald, at an been, ut te vast, ftit“anrct me
# ----
# iter 3500, loss: 63.150830
# ----
#  ela exlrae rool poleA—Jne
# ; mok a pal the and re
# cam
# hire. Mo Anall thig I thathed sour whoshild the no ghramvy un th or ho atorlor thoee
# chye
# curing
# rouck hhe jat wor arerthwpeibarl noos, the the thi
# ----
# iter 3600, loss: 62.617275
# ----
#  r, atehirkedAfYlas that htlanght
# the theangulpy reakinakessomn or-sede
# caes
# in soy bises had; too heeshlies in hatto halklest, ay wode dontedle;
# the bae; the sour, thathey crat them they, bis wal, the
# ----
# iter 3700, loss: 62.305841
# ----
#   o Nof
# wew het he Rrrig Setagar
# hed weee. dwer, the mor
#  hde
# Mey tik dobe
# er thon a mepes, the als, higt oren chofranfain srass of it han Jemen gagkse buvew4s a nhtanid meen
# tisate enachthey, inesdess
# ----
# iter 3800, loss: 62.194825
# ----
#  atis to s. Fo seruldnere hlee, bet gfos of des wilked wees wor a and peand fapdo
# sick niq rthined at tolset ibpem.
#  hime cart batines peeregeigher;
# of Bn, asit iese it the and yud
# amseen wales ongith,
# ----
# iter 3900, loss: 61.991945
# ----
#  I Piff The sxers gg, Wfum I
# geC, I fRle wa go tue Sτor thanl, the th ut io Fhasd.. fiky of —“O* bale;
# nCaw Ning m! PU., 1ur9awn
# Dn Thandes, brwate mLfertranourd taon qucl y ny be R1Ihrace crrooue PfC1
# ----
# iter 4000, loss: 62.586394
# ----
#  ase mermoas
# the th ood mat fore he aw, aliilcor cinict; wow a  hiwle
# atly, mebes wericim sirkes thit lrad tnod  onn oud to roor shall, rost par I ath thea pos, deet memee vablanxdenein, ias wo daald a
# ----
# iter 4100, loss: 62.431071
# ----
#  et harsuy one the me.
# mrous, mithemhes ther. W. Bafaig; atangy dromalt act.
# Wh  h. tou the
# tor shale me there, Mumnt klong re
# thallhced, te yilig bins, ofrel-ongice fark eooy—ultat,, Scat, neits tsane
# ----
# iter 4200, loss: 62.089505
# ----
#  e bef ar’ttle rroa soptaldtond, the
# ghe wy nupameit sithe nat widis, the shoone, in’sh. Fobut wyithott dondely—of in mabyer; sa pitor and of the
# stotets fuupt
# rtMingolr slonpite, loinvore weo the snye
# ----
# iter 4300, loss: 61.636955
# ----
#  ane an, puncacedts lim-ele efeavend din og fle
# jlye fyakef torled; feroot sor oule dobkingu poice anr inlasithuwd or and, for ant wisenandowint sout to s mels b thesess thatory gereetth, of fering fir
# ----
# iter 4400, loss: 61.331253
# ----
#   sanding not tund bonees to sime3cuedacpuistipement pons Jor berls; site heuve
# th, sit as,
# Susouey a domed hith sighach hinvesond
# wFoh ofmony haris whess  ha heunowdacs merdyid
# the Gor the aon
# riisin
# ----
# iter 4500, loss: 61.091029
# ----
#   pain he mowh; , ar thy ofrine for ofas (an, Bo.”
#
# HAty it holimeras, ofong latinnod, thivr boon voribg eadsowmiang mer alpapfraned inorlobd, hin pofer, Ilsibr,” surtsing heean. Jow mout—shalan to thi
# ----
# iter 4600, loss: 60.995207
# ----
#  r.
#
#
# Auntowas, leirghw toem
# f ay 6rateinind habe cimtec thener sterpatint thit daongong anm thall thiaof iat comt, Aud hlat or’s an, a heespat hat. Fung offer, varpivailket.
# ap. Soles atod on wule moU
# ----
# iter 4700, loss: 60.950503
# ----
#  therly ron k; and; acustar sus faf in winehh. Whe’s sattins (in poon. Iusans anle poff frap rouct hlaalw noer for he ine hat #for sino taiptarcinathe rlansimder skeirsezsself hit; at calin aann to  ne
# ----
# iter 4800, loss: 60.584568
# ----
#  heh this tlit sonr hos
# beos,, asnins seirreik as, hid wore the the to anpevtur Ppre drekl’g the steak. Jlaws aver the the siteredss sainde tio bics inand wengistras, be senterens thetine temmins anol
# ----
# iter 4900, loss: 60.280321
# ----
#  ngt hes hese hil hat
# he mote the farby th he bans ty Tandage the mrceacem—to i
# ” lasney
# plins ff tun Jod werade
# shond a aserfer migl shalit men horet eichas langy ance has the —withid
# bikit a the bit
# ----
# iter 5000, loss: 59.901798
# ----
#  und urq?an, merich; wrrow yole om tOThe the whaxt.
# ‘herd the to aw, Jrom wyth wich laon sand b wibeves weoll thit Jeailis taak huplled and whad wa ane sion thE ar, hiuds ad s-elon Lheunnow hoimenyen!!
# ----
# iter 5100, loss: 59.580627
# ----
#  unnet ha—N pan of I waring tou meche—selirg—fret a pede thaw be
# ond gonigh ho!po to ugte fishtnwaip of that; ars wius thingh thin sith toritt yeendingy spinge the bat Yromuths pan wisttund cleattof aJ
# ----
# iter 5200, loss: 59.367986
# ----
#  gis whing. thiw thanf
# Ised of e-milered xeed fofof as leor, tomlrnang the Ped featcafr5ocor! bo maeaut toredepcey
# neor to dy.
#
#
# an the crsaped ailuslred ans, the ate weet no fong ovkung this. Sarter g
# ----
# iter 5300, loss: 59.177265
# ----
#  e ther
# me apd, Ingased;
# hithes.
#
# I weat tangt otben kukingake meveit. noutamewingn terme fatesine I duledast on theed I mid
# thingt Hors, whemer
# noung pemere thee, pokmaveiug ned!
# blolrig aspacig como
# ----
# iter 5400, loss: 58.961019
# ----
#  sm thom
# sor din ballnund yo! no tand We mons a lorlr;
# ed mate in; butly ad; ith ty oplin hith onass sald I  hre the, soI of itile to gics aversaw; ouspes meresin; Bucay thot to Or brelt soubrnuct tha
# ----
# iter 5500, loss: 58.866712
# ----
#  et reot dout untha deden of bapol the shoth, at io merepece byfed bney of the gibrgllind ty sore corr; seet
# tomd so elakle fyes ban overs
# aled deree.
#
#  Bnoughy ofmungsy nomece he by fous wy the, ene a
# ----
# iter 5600, loss: 58.721422
# ----
#   thevontant eloshey; a
#  the sovears samcebef foung nond
# Jrepungis to S0mont he. foustny evacin teastey alikseatus hive bet and, anleqy withe ding Eanst
# ofout blerty rits baas sinet tE ald It waskus J
# ----
# iter 5700, loss: 58.719065
# ----
#  stiat ho and the sam serched whoughae, at hio farnines a teip lartny wor rough i fook nad withe ho
# rawh ; dingudl hachel’treishissald hiseas.
#
# I met ong of and dor hile, mine
# pebictheroted mas dis shi
# ----
# iter 5800, loss: 58.481720
# ----
#  r wharr this suins bor sounsoy and manmen heqwten guntiree in tor haboing ture betheqed Qubame ann cnope at art, strent whhed in a duentun, and buegfy, anden entupge ufeagnang ow thons aldith of fo fa
# ----
# iter 5900, loss: 58.343980
# ----
#  akning the ancag this. I arages ift ereas2rowg, he, sty’nd nredy the cipsser ang thecert ans
# kerade, entiung —nd Whasdrots.
#
# At
# ove he to hass bom, tho coerisiaed he, to wived a les the yindane andiot
# ----
# iter 6000, loss: 58.243320
# ----
#   of ritrener wime
# bull, of the
# catin thoughe ond a did iis as, ang theme ores.m
# hand das, ualeg Inded ble on. aH; a mayd minbil—he cupllith durnmedt
# podeghin oxk sloash Cluebonr, I thit go onterro, bl
# ----
# iter 6100, loss: 58.120916
# ----
#  in rere
# le
# wonqont or hingeleeryedaed ut sore, whe sigt. heworr let tat the derly in theas dich whe whis anans thig fe wo themess im thes,wy
# that, al of  it
# it
# and and anand amde the foth ities woog a
# ----
# iter 6200, loss: 57.981334
# ----
#  uns that—fuiptry stock hitliut chabee Qukllisk in unat,
# hasd seape’t thar a dave by favet—said the propkib foor in mar starten to thabriwt a
# rure nothe a mo sean that warkup mouk
# steenny set an clarut
# ----
# iter 6300, loss: 57.900923
# ----
#  t hesriband, meequd a my sounstitills pat hats. Thely foon trering frouttrodly of on in sicud whiwer ovis ineesiaiat of
# at it moo  to sising the myorp sicouns, erire; the he, piiron, aipet theta
# thiws
# ----
# iter 6400, loss: 57.880056
# ----
#  ik hind ig sismand thagkod ous wing and bcole, Higa-honc-tipw mrredsen, whes, hhefungmaidielee sFoold Bandrethl thike amday angoons he win-lico emeneing Ilders, loo, onowcud fraoloh treit th seuls sta
# ----
# iter 6500, loss: 57.668264
# ----
#  men eremfquct iqurded, Chame.
# “Brameret bugh’ the dussennt an Hy
# we the biins war thoups iming om ous,ed cetwly le whigs beres che of kube hingedseupmedas ar to
# lainging clare bus
#
# ilthe
# Sfadp weanrok
# ----
# iter 6600, loss: 57.732644
# ----
#   poeny ingong our or hact oushe.
#
# I
# bangeraonense of stcearyed thee, les
# be vey pyawld cotund heem, Mloun wan hant ovacoodtor his
# Fum. Qorl. Nang fraod ad osthimked
# ”Alleed
# bar and
# foor tan can s
# plav
# ----
# iter 6700, loss: 57.749465
# ----
#  ag wovy mond at bimein that
# hin ther bor councede
# whancing sitoren hios, or of stming, Oprer a dinongting and.
#
# HAed mat thle; the 5ord. Sut
# Bubcy by he sesing
# me? fit
# ”ustisterut to oy mup jlot Rfou
# ----
# iter 6800, loss: 57.822789
# ----
#  itelyemejancof, lome tiesh hink, Scoer in omokaest then haveith thatay forer the lalie, helle wout frortapris wheyt tong to wans of !Qdes ankmishsefot un mitel ce fof it profint-leesrut and tin tor ’n
# ----
# iter 6900, loss: 57.910063
# ----
#   thet nalpas stoulled Me oOpred hart wiler. I Domelne woor. morn,
# pros aike of then. Htou
#   min.”
#
# finsing and
# thawe a kerwe thanlchod sesite urtant—Afing bes beer fame,, rong chan ang a bemaaed to th
# ----
# iter 7000, loss: 57.853759
# ----
#  hagind
# ace nerised sheraa, whey ar spiit
# a
# nagdtr?routt of avin he hat ve he so gome mol’” a jlik?it ike, He Is hongt
# hat be ting last, Hif at omeles thass-jollait but aning bhouabarde anpef nou dorci
# ----
# iter 7100, loss: 57.796012
# ----
#   yollse theat the sofpraple semighiedulkedsine be fertorlmrtickoye, bocser; senater in omae
# aking poat” wokaol. Bune arliesedendCot IPwithenging thace o? thighierfismonR, of oe Nut avooferteald gout c
# ----
# iter 7200, loss: 57.601904
# ----
#  cavuares oblluat yot? of frim. To mahe of ture gow thiis lameds it ie
# nutel I thand herlia ablald sed hous
# chese Quokd illloon a feo eant
# mdilt llan’st is aun the
# seazatomtane weame ancreraceld, sbate
# ----
# iter 7300, loss: 57.675846
# ----
#  sericnys, In satlart wild suroug
# fes-laring
# Irond ixs wasencrim mower thoo cllistase ap ovoun shen are sited thass, hin, the sald—darinseved wastind sumat stap ti s, war; the Hil; is the doon mowedis—
# ----
# iter 7400, loss: 57.661608
# ----
#  nd ale shew, drote lrovang
# te zond nont phait in gome of ig a dupprall, ind he Saw “reont bedigime she tine thy pas dy a ind eoffde to the an there do good stoagen sveea shaty he. Thas ppobd fomitere
# ----
# iter 7500, loss: 57.537633
# ----
#   chagce whell ce
# this to sepite Qey bald Ilc, and memtred on, pitey, whagter, bed latly ondingredist irly Butthincy sIs ale tre to
# hit heay eves, a them, wat somim, whaX.” a den, nptloont. homan edat,
# ----
# iter 7600, loss: 57.440855
# ----
#   Bour naflay oulfallef hiw?”
#
# In Iugtwod ad
# tholf le findtongl a, forre srek intust Cmone.
# Whildiw iE I him!t
# I waveedy, last, ougr uhfivly he thictenced . douthad sad precty it” bupe has had foind mi
# ----
# iter 7700, loss: 57.448454
# ----
#  etlill ferae naph uchaml, weoring in feam and deer and at OKsth;
# suoim-non tount yoved lit iThat! An
# ione bef, were vamch Plvi2stilers, fus. I hit and hat kere
# tor ald an to Cal axe
# cou Qutris ot? whe
# ----
# iter 7800, loss: 57.349099
# ----
#  ss on mow, mad in mird flafe. a theer ta hice CI mome astithey ipit aod on handy mut at
# Otout ape, supeaswipe Sit
# aws way vabed bupk of him hid
# sat waw haid of the a arl set’t mort. Tho whlernig a met
# ----
# iter 7900, loss: 57.330627
# ----
#  t of
# of gors.
# a
# dupquroiny kiater Caviagn extorg. Bould rout
# urape abd.”
# “Anedesbo or he elin
# mole moid Peens re the meom-tom sin merly—beof, and ces” him eBver sionttors?—I thit ther hice
# I raveesf.h
# ----
# iter 8000, loss: 57.293721
# ----
#  s torery hiI witund cherontcuite the ars!
#
# foupbriot’tly mat hat were the
# “of the tyate, I even?
#
# to tromfhes this. Pay Pofs, yod the cand itemand atraoong I
# ““Bry of of cane ther,—wat ap, ine in tous
# ----
# iter 8100, loss: 57.319720
# ----
#  at hinghe, seisld is pret foor rot anterig thes wane
# the the s, moubn filn at, il com-it to sharh wat afIlerel! lloilt Bt
# lasp.
#
#  “dor mat of thit hithed pod the mitt colliat whacees at, If lre foatra
# ----
# iter 8200, loss: 57.150188
# ----
#   mor to ow in hink in hastee wak steyfeenaid ipish; f’s las a ; jo9e tore te
# sterpedtin wiad frover k Ie. Be asy.
#
#
# “Whart a domaver or.” avin whe ane I hing of, the tor thim. “heting storrit-in ceree
# ----
# iter 8300, loss: 56.915249
# ----
#  e they’s the ctrrere
# by “the foir torr o thicle womlily witishthith med to clis wan wo I rimail of tirip the komemen veurlroat thand andt had
# un ny mbreced aliue sist the wat so )e
# soich pveckew in ov
# ----
# iter 8400, loss: 56.822619
# ----
#  t weut
# at
# he
# qeom in
# ingtert he toch, Wheing
# revimort
# hisbyom chahl’s, Rut, ande berioon, beew out Nom.”
# lamt he capedt quebuikh, siane nistrennad, the agin sepone
# degunn meaciadrn bse, sheins dam rin
# ----
# iter 8500, loss: 56.898298
# ----
#  singnsom than Ciwhers cedtavew hinsen richaps and oner, lit ’t sereepiresaciok” woriedin rudan the pasted Qupsoue head so-bored, no prew thoutty of thay deet an
# ard trow llet reecrorg ansant an sam at
# ----
# iter 8600, loss: 56.856419
# ----
#  nd ukling orat to To to on ! Id, il?”
#
# “Dy chemy im
# ened thous bees. Ind and net noce—a and ag thris soos plong,” at-that yithevord, Ind that Dhonde beoche haspand uptiestias or tany.”
#
# Buld ang sthe?
# ----
# iter 8700, loss: 56.901562
# ----
#  tooll butpoly hapk On the rurket; hansti, gpsee, vike, f an’s on the hard pah; biprat ferkt
# wale the orer an it sout meaph the beit ard, whibes. He inuscag the wanay Bcing the sheret” Quong ansatilonn
# ----
# iter 8800, loss: 56.801281
# ----
#  out seald on; the naming’ssyy paboigleed onoue reay.”
# “I mall lestisey samanf larghaskoue b, shiting hind
# “Awat; Flack to the atony shither.” udubes-laprexein, saud breound, ke? ths wow
# tros. ““Whall
# ----
# iter 8900, loss: 56.645814
# ----
#   eed, aha of a
# Beed
# so reboured whing hip’ she hes, Ilduncwied,
# slaggincen. Ham, labe the sere! Anlask he sting sealish igpatnand’d op gushat foy thing
# hach. nes thed prag, of ny met me ne! Bick’s in
# ----
# iter 9000, loss: 56.495327
# ----
#  lalt a Orereed, Juth cere,
# sherl whiklagn lrin, “he cunt, I hath, monger, Withe Clath hat cles yonsillesing. I beowas,
# ding thow and hound eceewest cop ard sab;, soy grtonpain, as ol’s cline in the th
# ----
# iter 9100, loss: 56.272188
# ----
#  the thak,
# “Hgnatomyameiche brexhin hid the
# son butt’ng re; yo whougwit ethe suim thangolis lecces serlind to tyes uhned wich
#  a shit, Alvobowinge rore, the kies, list olugingen to a did, of that chore
# ----
# iter 9200, loss: 56.137741
# ----
#  thing blacken evaincy; oby sreostod boes that cabvir
# was hy, ther speld feldet a woolut toflaict ovy thit tove, noten th tas
# shiths, Enon.”
#
# I goidce.”
# Boik of sreping
# hing eluen insting lilh aumly se
# ----
# iter 9300, loss: 56.215576
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 100
#      97   print('----\n %s \n----' % (txt, ))
#      99 # forward seq_length characters through the net and fetch gradient
# --> 100 loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#     101 smooth_loss = smooth_loss * 0.999 + loss * 0.001
#     102 if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
#
# Cell In[3], line 40, in lossFun(inputs, targets, hprev)
#      38 xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
#      39 xs[t][inputs[t]] = 1
# ---> 40 hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      41 ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
#      42 ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#
# KeyboardInterrupt:
